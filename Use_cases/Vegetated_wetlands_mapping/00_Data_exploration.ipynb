# %% [markdown]
# # Data Exploration and Analysis

# %% [markdown]
# The two training data ESRI shapefiles provided `Yearly Training Sites_kenya and Uganda\\Yearly_Point_Data_Uganda.shp` and `Yearly Training Sites_kenya and Uganda\\Yearly_Point_Data_Kenya.shp` did not have any coordinate reference system.
# They were assigned the `EPSG:4326` coordinate reference system in QGIS before being merged and exported as a `GeoJSON` file. The two columns `layer` and `path` were dropped from the file in QGIS and the resulting `GeoJSoN` file was uploaded into the sandbox.

# %% [markdown]
# ## Load packages

# %%
import json

import geopandas as gpd
import numpy as np
import pandas as pd
from shapely.geometry import box

# %% [markdown]
# ## Load the training data

# %%
training_data_fp = "data/kenya_uganda_yearly_point_training_sites.geojson"

# %%
training_data_gdf = gpd.read_file(training_data_fp)
training_data_gdf.head()
# Out:
#    plotid  year country  country_id  latitude  longitude         landcover  \
# 0       2  1985   kenya           7  4.371003  35.746118    Open Grassland
# 1       3  1985   kenya           7 -0.524994  40.402437  Wooded Grassland
# 2       4  1985   kenya           7  0.535051  40.435959  Wooded Grassland
# 3       7  1985   kenya           7  0.251115  36.293126          Cropland
# 4       8  1985   kenya           7  4.099182  37.396270    Open Grassland
#
#                     geometry
# 0   POINT (35.74612 4.37100)
# 1  POINT (40.40244 -0.52499)
# 2   POINT (40.43596 0.53505)
# 3   POINT (36.29313 0.25112)
# 4   POINT (37.39627 4.09918)

# %%
# Check if the training data has a coordinate reference system.
training_data_gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# The training data is in point geometry.
# The shapefiles each have 8 columns:
# * `plotid`:
# * `year`: The year the training data was collected.
# * `country`: The country either Kenya or Uganda.
# * `country_id`: The country id is either `5` for `uganda` or `7` for `kenya`.
# * `lattitude`: The lattitude coordinate (EPSG:4326) for the training data point.
# * `longitude`: The longitude coordinate (EPSG:4326) for the training data point.
# * `landcover`: The land cover class the point represents.
# * `geometry`: The point geometry of training point in EPSG:4326 crs.

# %% [markdown]
# ### Assign a unique integer value to represent each land cover class

# %%
# Get a list of the unique land cover classes in the data.
class_names = np.unique(training_data_gdf.landcover)
class_names
# Out:
# array(['Cropland', 'Dense Forest', 'Open Forest', 'Open Grassland',
#        'Open Water', 'Otherland', 'Settlements', 'Vegetated Wetland',
#        'Wooded Grassland'], dtype=object)

# %%
# Get a list of unique integer values to assign to each land cover class.
class_values = list(range(1, len(class_names) + 1))
class_values
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
# Generate a dictionary mapping the 'string' name of the classes to the integer values that represent the land cover classes in the training data.
class_dict = dict(zip(class_names, class_values))
class_dict
# Out:
# {'Cropland': 1,
#  'Dense Forest': 2,
#  'Open Forest': 3,
#  'Open Grassland': 4,
#  'Open Water': 5,
#  'Otherland': 6,
#  'Settlements': 7,
#  'Vegetated Wetland': 8,
#  'Wooded Grassland': 9}

# %%
# Class colors
class_colors = [
    "#F096FF",
    "#007800",
    "#648C00",
    "#FFBB22",
    "#0032C8",
    "#B4B4B4",
    "#FA0000",
    "#0096A0",
    "#FFFF4C",
]

class_color_dict = dict(zip(class_names, class_colors))
class_color_dict
# Out:
# {'Cropland': '#F096FF',
#  'Dense Forest': '#007800',
#  'Open Forest': '#648C00',
#  'Open Grassland': '#FFBB22',
#  'Open Water': '#0032C8',
#  'Otherland': '#B4B4B4',
#  'Settlements': '#FA0000',
#  'Vegetated Wetland': '#0096A0',
#  'Wooded Grassland': '#FFFF4C'}

# %%
labels = {}
for class_name, class_value in class_dict.items():
    labels[class_value] = {'color': class_color_dict[class_name], 'flag': class_name}
    
labels
# Out:
# {1: {'color': '#F096FF', 'flag': 'Cropland'},
#  2: {'color': '#007800', 'flag': 'Dense Forest'},
#  3: {'color': '#648C00', 'flag': 'Open Forest'},
#  4: {'color': '#FFBB22', 'flag': 'Open Grassland'},
#  5: {'color': '#0032C8', 'flag': 'Open Water'},
#  6: {'color': '#B4B4B4', 'flag': 'Otherland'},
#  7: {'color': '#FA0000', 'flag': 'Settlements'},
#  8: {'color': '#0096A0', 'flag': 'Vegetated Wetland'},
#  9: {'color': '#FFFF4C', 'flag': 'Wooded Grassland'}}

# %%
# Add a new column 'class'.
training_data_gdf["class"] = training_data_gdf["landcover"].map(class_dict)
training_data_gdf.head()
# Out:
#    plotid  year country  country_id  latitude  longitude         landcover  \
# 0       2  1985   kenya           7  4.371003  35.746118    Open Grassland
# 1       3  1985   kenya           7 -0.524994  40.402437  Wooded Grassland
# 2       4  1985   kenya           7  0.535051  40.435959  Wooded Grassland
# 3       7  1985   kenya           7  0.251115  36.293126          Cropland
# 4       8  1985   kenya           7  4.099182  37.396270    Open Grassland
#
#                     geometry  class
# 0   POINT (35.74612 4.37100)      4
# 1  POINT (40.40244 -0.52499)      9
# 2   POINT (40.43596 0.53505)      9
# 3   POINT (36.29313 0.25112)      1
# 4   POINT (37.39627 4.09918)      4

# %% [markdown]
# ## Convert the points to polygons.

# %%
# Function to get a square polygon from a point.
def polygon_from_centroid(point):
    # Buffer was assumed from the `crop_training_qgypt.geojson` file.
    buffer = 0.0015
    # Buffer fromm the number of decimal places in the coordinates.
    # buffer = 0.000001 # this does not work
    minx = point.geometry.x - buffer
    miny = point.geometry.y - buffer
    maxx = point.geometry.x + buffer
    maxy = point.geometry.y + buffer
    polygon = box(minx, miny, maxx, maxy, ccw=True)

    return polygon


# Convert the points to polygons.
training_data_gdf["polygon"] = training_data_gdf.apply(polygon_from_centroid, axis=1)

# Change the geometry of the GeoDataFrame to the `polygon` column.
training_data_gdf.set_geometry(col="polygon", drop=True, inplace=True, crs="EPSG:4326")

training_data_gdf
# Out:
#         plotid  year country  country_id  latitude  longitude  \
# 0            2  1985   kenya           7  4.371003  35.746118
# 1            3  1985   kenya           7 -0.524994  40.402437
# 2            4  1985   kenya           7  0.535051  40.435959
# 3            7  1985   kenya           7  0.251115  36.293126
# 4            8  1985   kenya           7  4.099182  37.396270
# ...        ...   ...     ...         ...       ...        ...
# 131158    1996  2017  uganda           5 -0.920187  32.356140
# 131159    1997  2017  uganda           5  0.917003  30.356584
# 131160    1998  2017  uganda           5  2.538681  32.146721
# 131161    1999  2017  uganda           5  3.101875  31.890663
# 131162    2000  2017  uganda           5  0.675772  31.814430
#
#                landcover                                           geometry  \
# 0         Open Grassland  POLYGON ((35.74762 4.36950, 35.74762 4.37250, ...
# 1       Wooded Grassland  POLYGON ((40.40394 -0.52649, 40.40394 -0.52349...
# 2       Wooded Grassland  POLYGON ((40.43746 0.53355, 40.43746 0.53655, ...
# 3               Cropland  POLYGON ((36.29463 0.24962, 36.29463 0.25262, ...
# 4         Open Grassland  POLYGON ((37.39777 4.09768, 37.39777 4.10068, ...
# ...                  ...                                                ...
# 131158        Open Water  POLYGON ((32.35764 -0.92169, 32.35764 -0.91869...
# 131159    Open Grassland  POLYGON ((30.35808 0.91550, 30.35808 0.91850, ...
# 131160    Open Grassland  POLYGON ((32.14822 2.53718, 32.14822 2.54018, ...
# 131161       Open Forest  POLYGON ((31.89216 3.10038, 31.89216 3.10338, ...
# 131162    Open Grassland  POLYGON ((31.81593 0.67427, 31.81593 0.67727, ...
#
#         class
# 0           4
# 1           9
# 2           9
# 3           1
# 4           4
# ...       ...
# 131158      5
# 131159      4
# 131160      4
# 131161      3
# 131162      4
#
# [131163 rows x 9 columns]

# %% [markdown]
# ### Save as a GeoJSON

# %%
# Get the training data for each year.
years = np.unique(training_data_gdf["year"])
for year in years:
    selected_training_data = training_data_gdf[training_data_gdf["year"] == year]
    # Drop unneccesary columns.
    selected_training_data = selected_training_data[["class", "geometry"]]
    # Save to GeoJSON
    selected_training_data.to_file(
        f"data/kenya_uganda_yearly_polygon_training_sites_{year}.geojson",
        driver="GeoJSON",
    )

# %% [markdown]
# ## Data Exploration

# %%
# Find the number of training points available for each land cover class for each year.
years = np.unique(training_data_gdf["year"])

print(f"Training data for all years {years.min()} to {years.max()}:")
print(training_data_gdf["landcover"].value_counts())

for year in years:
    selected_training_data = training_data_gdf[training_data_gdf["year"] == year]
    print(f"\nTraining data for the year {year}:")
    print(selected_training_data["landcover"].value_counts())
# Out:
# Training data for all years 1985 to 2017:
# Wooded Grassland     43454
# Open Grassland       30122
# Cropland             23093
# Open Water           11258
# Otherland             9376
# Open Forest           6653
# Dense Forest          4929
# Vegetated Wetland     1743
# Settlements            535
# Name: landcover, dtype: int64
#
# Training data for the year 1985:
# Wooded Grassland     1057
# Open Grassland        755
# Cropland              462
# Open Water            308
# Otherland             273
# Open Forest           161
# Dense Forest          119
# Vegetated Wetland      39
# Settlements            13
# Name: landcover, dtype: int64
#
# Training data for the year 1986:
# Wooded Grassland     1377
# Open Grassland        940
# Cropland              606
# Open Water            342
# Otherland             285
# Open Forest           216
# Dense Forest          157
# Vegetated Wetland      55
# Settlements            13
# Name: landcover, dtype: int64
#
# Training data for the year 1987:
# Wooded Grassland     1375
# Open Grassland        941
# Cropland              612
# Open Water            342
# Otherland             285
# Open Forest           217
# Dense Forest          158
# Vegetated Wetland      55
# Settlements            13
# Name: landcover, dtype: int64
#
# Training data for the year 1988:
# Wooded Grassland     1375
# Open Grassland        941
# Cropland              612
# Open Water            342
# Otherland             285
# Open Forest           217
# Dense Forest          158
# Vegetated Wetland      55
# Settlements            13
# Name: landcover, dtype: int64
#
# Training data for the year 1989:
# Wooded Grassland     1375
# Open Grassland        941
# Cropland              612
# Open Water            342
# Otherland             285
# Open Forest           217
# Dense Forest          158
# Vegetated Wetland      55
# Settlements            13
# Name: landcover, dtype: int64
#
# Training data for the year 1990:
# Wooded Grassland     1375
# Open Grassland        941
# Cropland              612
# Open Water            342
# Otherland             285
# Open Forest           217
# Dense Forest          158
# Vegetated Wetland      55
# Settlements            13
# Name: landcover, dtype: int64
#
# Training data for the year 1991:
# Wooded Grassland     1375
# Open Grassland        941
# Cropland              612
# Open Water            342
# Otherland             285
# Open Forest           217
# Dense Forest          158
# Vegetated Wetland      55
# Settlements            13
# Name: landcover, dtype: int64
#
# Training data for the year 1992:
# Wooded Grassland     1375
# Open Grassland        941
# Cropland              612
# Open Water            342
# Otherland             285
# Open Forest           217
# Dense Forest          158
# Vegetated Wetland      55
# Settlements            13
# Name: landcover, dtype: int64
#
# Training data for the year 1993:
# Wooded Grassland     1375
# Open Grassland        941
# Cropland              612
# Open Water            342
# Otherland             285
# Open Forest           217
# Dense Forest          158
# Vegetated Wetland      55
# Settlements            13
# Name: landcover, dtype: int64
#
# Training data for the year 1994:
# Wooded Grassland     1375
# Open Grassland        940
# Cropland              616
# Open Water            342
# Otherland             284
# Open Forest           215
# Dense Forest          157
# Vegetated Wetland      56
# Settlements            14
# Name: landcover, dtype: int64
#
# Training data for the year 1995:
# Wooded Grassland     1369
# Open Grassland        935
# Cropland              627
# Open Water            342
# Otherland             284
# Open Forest           216
# Dense Forest          157
# Vegetated Wetland      56
# Settlements            14
# Name: landcover, dtype: int64
#
# Training data for the year 1996:
# Wooded Grassland     1369
# Open Grassland        936
# Cropland              627
# Open Water            342
# Otherland             284
# Open Forest           215
# Dense Forest          157
# Vegetated Wetland      56
# Settlements            14
# Name: landcover, dtype: int64
#
# Training data for the year 1997:
# Wooded Grassland     1369
# Open Grassland        936
# Cropland              627
# Open Water            342
# Otherland             284
# Open Forest           215
# Dense Forest          157
# Vegetated Wetland      56
# Settlements            14
# Name: landcover, dtype: int64
#
# Training data for the year 1998:
# Wooded Grassland     1369
# Open Grassland        936
# Cropland              627
# Open Water            342
# Otherland             284
# Open Forest           215
# Dense Forest          157
# Vegetated Wetland      56
# Settlements            14
# Name: landcover, dtype: int64
#
# Training data for the year 1999:
# Wooded Grassland     1360
# Open Grassland        936
# Cropland              640
# Open Water            343
# Otherland             284
# Open Forest           212
# Dense Forest          156
# Vegetated Wetland      55
# Settlements            14
# Name: landcover, dtype: int64
#
# Training data for the year 2000:
# Wooded Grassland     1346
# Open Grassland        932
# Cropland              665
# Open Water            344
# Otherland             284
# Open Forest           206
# Dense Forest          155
# Vegetated Wetland      53
# Settlements            15
# Name: landcover, dtype: int64
#
# Training data for the year 2001:
# Wooded Grassland     1340
# Open Grassland        931
# Cropland              674
# Open Water            341
# Otherland             285
# Open Forest           205
# Dense Forest          155
# Vegetated Wetland      53
# Settlements            16
# Name: landcover, dtype: int64
#
# Training data for the year 2002:
# Wooded Grassland     1335
# Open Grassland        926
# Cropland              690
# Open Water            341
# Otherland             285
# Open Forest           202
# Dense Forest          153
# Vegetated Wetland      52
# Settlements            16
# Name: landcover, dtype: int64
#
# Training data for the year 2003:
# Wooded Grassland     1331
# Open Grassland        923
# Cropland              701
# Open Water            341
# Otherland             285
# Open Forest           199
# Dense Forest          151
# Vegetated Wetland      52
# Settlements            17
# Name: landcover, dtype: int64
#
# Training data for the year 2004:
# Wooded Grassland     1325
# Open Grassland        919
# Cropland              712
# Open Water            343
# Otherland             284
# Open Forest           198
# Dense Forest          151
# Vegetated Wetland      51
# Settlements            17
# Name: landcover, dtype: int64
#
# Training data for the year 2005:
# Wooded Grassland     1323
# Open Grassland        914
# Cropland              722
# Open Water            344
# Otherland             283
# Open Forest           196
# Dense Forest          150
# Vegetated Wetland      51
# Settlements            17
# Name: landcover, dtype: int64
#
# Training data for the year 2006:
# Wooded Grassland     1311
# Open Grassland        909
# Cropland              739
# Open Water            341
# Otherland             285
# Open Forest           196
# Dense Forest          149
# Vegetated Wetland      52
# Settlements            18
# Name: landcover, dtype: int64
#
# Training data for the year 2007:
# Wooded Grassland     1305
# Open Grassland        906
# Cropland              750
# Open Water            344
# Otherland             283
# Open Forest           194
# Dense Forest          149
# Vegetated Wetland      51
# Settlements            18
# Name: landcover, dtype: int64
#
# Training data for the year 2008:
# Wooded Grassland     1304
# Open Grassland        899
# Cropland              764
# Open Water            342
# Otherland             284
# Open Forest           191
# Dense Forest          146
# Vegetated Wetland      52
# Settlements            18
# Name: landcover, dtype: int64
#
# Training data for the year 2009:
# Wooded Grassland     1289
# Open Grassland        896
# Cropland              784
# Open Water            341
# Otherland             285
# Open Forest           191
# Dense Forest          144
# Vegetated Wetland      52
# Settlements            18
# Name: landcover, dtype: int64
#
# Training data for the year 2010:
# Wooded Grassland     1279
# Open Grassland        895
# Cropland              798
# Open Water            342
# Otherland             284
# Open Forest           192
# Dense Forest          140
# Vegetated Wetland      52
# Settlements            18
# Name: landcover, dtype: int64
#
# Training data for the year 2011:
# Wooded Grassland     1270
# Open Grassland        888
# Cropland              816
# Open Water            342
# Otherland             284
# Open Forest           189
# Dense Forest          140
# Vegetated Wetland      52
# Settlements            19
# Name: landcover, dtype: int64
#
# Training data for the year 2012:
# Wooded Grassland     1258
# Open Grassland        884
# Cropland              831
# Open Water            343
# Otherland             283
# Open Forest           188
# Dense Forest          141
# Vegetated Wetland      52
# Settlements            20
# Name: landcover, dtype: int64
#
# Training data for the year 2013:
# Wooded Grassland     1248
# Open Grassland        876
# Cropland              847
# Open Water            343
# Otherland             283
# Open Forest           189
# Dense Forest          141
# Vegetated Wetland      52
# Settlements            21
# Name: landcover, dtype: int64
#
# Training data for the year 2014:
# Wooded Grassland     1239
# Open Grassland        879
# Cropland              860
# Open Water            341
# Otherland             286
# Open Forest           186
# Dense Forest          136
# Vegetated Wetland      52
# Settlements            21
# Name: landcover, dtype: int64
#
# Training data for the year 2015:
# Wooded Grassland     1235
# Open Grassland        880
# Cropland              865
# Open Water            342
# Otherland             286
# Open Forest           186
# Dense Forest          134
# Vegetated Wetland      51
# Settlements            21
# Name: landcover, dtype: int64
#
# Training data for the year 2016:
# Wooded Grassland     1226
# Open Grassland        883
# Cropland              871
# Open Water            343
# Otherland             285
# Open Forest           185
# Dense Forest          134
# Vegetated Wetland      51
# Settlements            22
# Name: landcover, dtype: int64
#
# Training data for the year 2017:
# Wooded Grassland     1220
# Cropland              888
# Open Grassland        881
# Open Water            343
# Otherland             285
# Open Forest           176
# Dense Forest          137
# Vegetated Wetland      48
# Settlements            22
# Name: landcover, dtype: int64
